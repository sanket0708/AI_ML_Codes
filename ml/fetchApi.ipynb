# %%
import numpy as np

# %%
import requests
import pandas as pd

# %%
url = 'https://sportapi7.p.rapidapi.com/api/v1/player/750'
headers = {
	"x-rapidapi-key": "cddd97d10bmshb173db3d405a0ffp178473jsn0a4c87c0eda9",
	"x-rapidapi-host": "sportapi7.p.rapidapi.com",
	"Content-Type": "application/json"
}

# %%
response = requests.get(url,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                                    player
# name                                                    Cristiano Ronaldo
# slug                                                    cristiano-ronaldo
# shortName                                                      C. Ronaldo
# team                    {'name': 'Al-Nassr', 'slug': 'al-nassr', 'shor...
# position                                                                F
# positionsDetailed                                                    [ST]
# jerseyNumber                                                            7
# height                                                                187
# dateOfBirth                                     1985-02-05T00:00:00+00:00
# preferredFoot                                                       Right
# userCount                                                         2713498
# deceased                                                            False
# gender                                                                  M
# sofascoreId                                                           CR7
# country                 {'alpha2': 'PT', 'alpha3': 'PRT', 'name': 'Por...
# id                                                                    750
# shirtNumber                                                             7
# dateOfBirthTimestamp                                            476409600
# contractUntilTimestamp                                         1814313600
# proposedMarketValue                                              12500000
# proposedMarketValueRaw             {'value': 12500000, 'currency': 'EUR'}
# fieldTranslations       {'nameTranslation': {'ar': 'كريستيانو رونالدو'...

# %%
df.shape
# Out:
# (22, 1)
