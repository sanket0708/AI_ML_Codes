# %% [markdown]
# <a href="https://colab.research.google.com/github/sanket0708/AI_ML_Codes/blob/main/dl/moviematch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('movies_metadata.csv')

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df = df.drop_duplicates().reset_index(drop=True) #discarding the old index as well

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45448  False                                                NaN         0
# 45449  False                                                NaN         0
# 45450  False                                                NaN         0
# 45451  False                                                NaN         0
# 45452  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df[['title','overview','genres','tagline','vote_average','popularity']]

# %%
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45448                       Subdue
# 45449          Century of Birthing
# 45450                     Betrayal
# 45451             Satan Triumphant
# 45452                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45448        Rising and falling between a man and woman.
# 45449  An artist struggles to finish his work while a...
# ...

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                              tagline  vote_average popularity
# ...

# %%
df = df.dropna(subset=['title']) #drop the title who has nan value

# %%
df.isnull().sum()
# Out:
# title               0
# overview          954
# genres              0
# tagline         25039
# vote_average        0
# popularity          0
# dtype: int64

# %%
df['overview'] = df['overview'].fillna('') # fill empty space in nan in overview

# %%
df.isnull().sum()
# Out:
# title               0
# overview            0
# genres              0
# tagline         25039
# vote_average        0
# popularity          0
# dtype: int64

# %%
df.iloc[1]['genres'] #list type , dictionary
import ast

# %%
df['genres'] = df['genres'].apply(lambda x :" ".join([i['name'] for i in ast.literal_eval(x)]))

# %%
df.iloc[1]['genres']
# Out:
# 'Adventure Fantasy Family'

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                NaN           7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df['tagline'] = df['tagline'].fillna('') # fill empty space in nan in tagline

# %%
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45448                       Subdue
# 45449          Century of Birthing
# 45450                     Betrayal
# 45451             Satan Triumphant
# 45452                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45448        Rising and falling between a man and woman.
# 45449  An artist struggles to finish his work while a...
# ...

# %%
df.isnull().sum()
# Out:
# title           0
# overview        0
# genres          0
# tagline         0
# vote_average    0
# popularity      0
# dtype: int64

# %%
# combine overview , genre and tagline ( for nlp processing )

df['tags'] = df['overview'] + " " + df['genres'] + " " + df['tagline']
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45448                       Subdue
# 45449          Century of Birthing
# 45450                     Betrayal
# 45451             Satan Triumphant
# 45452                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45448        Rising and falling between a man and woman.
# 45449  An artist struggles to finish his work while a...
# ...

# %%
df.iloc[1]['tags']
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %% [markdown]
# ## **PRE PROCESSING AND DATA CLEANING DONE **

# %%
df['tags'][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %%
# REMOVE THE PUNCTUATION in nlp like , ' ! , so that we can apply cosine similarity
# as well remove "and" , "the" , "to" , "or" and so on they dont depict any important information

# %%
#then we split the words , because i have to create a token , before token do lemmatization

# %%
# lemmatization - what is means is ex- ending and end is almost same that is end

# %%
import nltk

# %%
from nltk.corpus import stopwords #like when , the , to , at
from nltk.stem import WordNetLemmatizer # ended and end are same
import re #regular expression

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

#made objects of this classes

# %%
def preprocess_text(text):
  text = str(text).lower() #lowercase everything first
  text = re.sub(r'[^a-zA-Z\s]', '', text) # Remove punctuation
  words = text.split() # here basically we have divided words in tokens

  #remove stopwords
  words = [word for word in words if word not in stop_words]

  #now lemmatize
  words = [lemmatizer.lemmatize(word) for word in words]

  return " ".join(words)

# %%
df['tags'] = df['tags'].apply(preprocess_text)

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df['tags'][1]
# Out:
# 'sibling judy peter discover enchanted board game open door magical world unwittingly invite alan adult who trapped inside game year living room alans hope freedom finish game prof risky three find running giant rhinoceros evil monkey terrifying creature adventure fantasy family roll dice unleash excitement'

# %% [markdown]
# ## **NLP Text preprocessing done and we have remove all the unnecessary words from tags column **

# %%
df = df.reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# title           0
# overview        0
# genres          0
# tagline         0
# vote_average    0
# popularity      0
# tags            0
# dtype: int64

# %%
indices = pd.Series(df.index, index=df['title']).drop_duplicates()

# %%
indices
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Subdue                         45442
# Century of Birthing            45443
# Betrayal                       45444
# Satan Triumphant               45445
# Queerama                       45446
# Length: 45447, dtype: int64

# %%
#apply vectorization , a big sentence into numbers using tf-idf

# term frequency and inverse document frequency

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=50000,stop_words='english',ngram_range=(1,2))

# %%
tfidf_matrix = tfidf.fit_transform(df['tags'])

# every tags will be converted to vector and then will be converted to 2d that is matrix

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1548114 stored elements and shape (45447, 50000)>

# %% [markdown]
# ## **COSINE SIMILARITY TO PREDICT MOVIES **

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(title,n=10): #10 movies can be recommended by default
  if(title not in indices):
    return ['Movie not found!']

  idx = indices[title]
  similarity_score = cosine_similarity(tfidf_matrix[idx],tfidf_matrix).flatten()
  similar_index = similarity_score.argsort()[::-1][1:n+1] #sort basis on index top 10 index and then top 10 index
  return df['title'].iloc[similar_index] #return top 10 similar movies

# %%
recommend("Toy Story")
# Out:
# 2996                Toy Story 2
# 15344               Toy Story 3
# 24512                 Small Fry
# 28972           Superstar Goofy
# 17184                 Group Sex
# 6434     What's Up, Tiger Lily?
# 11396    For Your Consideration
# 1071      Rebel Without a Cause
# 1931                  Condorman
# 485                      Malice
# Name: title, dtype: object

# %%
recommend("Avenger")
# Out:
# 41886     Dexter's Laboratory: Ego Trip
# 4367                             D.O.A.
# 25089                  Hit by Lightning
# 12061                 The Hunting Party
# 871              The Philadelphia Story
# 5054                          Hopscotch
# 7842     Now You See Him, Now You Don't
# 584                    Tough and Deadly
# 7871                       The Escapist
# 34012                      Sharpshooter
# Name: title, dtype: object

# %%
# export the model
import pickle

pickle.dump(tfidf_matrix,open('tfidf_matrix.pkl','wb'))
pickle.dump(indices,open('indices.pkl','wb'))
df.to_pickle('df.pkl')
pickle.dump(tfidf,open('tfidf.pkl','wb'))
